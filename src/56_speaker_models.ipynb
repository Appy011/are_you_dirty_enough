# %%
import librosa
import wave, os, glob
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import LabelEncoder, StandardScaler

from keras import models
from keras import layers
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Creating CSV file

# %%
"""

creating a list of headings

"""

header = 'filename chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
for i in range(1, 21):
    header += f' mfcc{i}'
header += ' label'
header = header.split()

# %%
clean_filenames = glob.glob('clean_trainset_56/*')

# %%
noisy_filenames = glob.glob('noisy_trainset_56/*')

# %%
total_filenames = clean_filenames[:2500] + noisy_filenames[:2500]
len(total_filenames)
# Out:
# 5000

# %% [markdown]
# # Adding 56 Speaker Clean Data

# %%
sr = 48000

"""

opening and writing the headings to a csv file

"""

file = open('56spk_data.csv', 'w', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)


"""

Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

"""


for filename in clean_filenames[:5000]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
print(len(clean_filenames))
print(len(noisy_filenames))
# Out:
# 23075
# 23075

# %%
"""
Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

5,000 - 10,000

"""


for filename in clean_filenames[5000:10000]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
"""
Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

10,000 - 15,000

"""


for filename in clean_filenames[10000:15000]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
"""
Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

15,000 - 20,000

"""


for filename in clean_filenames[15000:20000]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())
# Out:
# /opt/conda/lib/python3.7/site-packages/librosa/core/pitch.py:146: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')

# %%
"""
Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

20,000 - 23,075

"""


for filename in clean_filenames[20000:23075]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
clean_files_raw = pd.read_csv('56spk_data.csv')

# %%
clean_files = clean_files_raw[:]

# %%
clean_files.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23075 entries, 0 to 23074
# Data columns (total 28 columns):
# filename              23075 non-null object
# chroma_stft           23075 non-null float64
# rmse                  23075 non-null float64
# spectral_centroid     23075 non-null float64
# spectral_bandwidth    23075 non-null float64
# rolloff               23075 non-null float64
# zero_crossing_rate    23075 non-null float64
# mfcc1                 23075 non-null float64
# mfcc2                 23075 non-null float64
# mfcc3                 23075 non-null float64
# mfcc4                 23075 non-null float64
# mfcc5                 23075 non-null float64
# mfcc6                 23075 non-null float64
# mfcc7                 23075 non-null float64
# mfcc8                 23075 non-null float64
# mfcc9                 23075 non-null float64
# mfcc10                23075 non-null float64
# mfcc11                23075 non-null float64
# mfcc12                23075 non-null float64
# mfcc13                23075 non-null float64
# mfcc14                23075 non-null float64
# mfcc15                23075 non-null float64
# mfcc16                23075 non-null float64
# mfcc17                23075 non-null float64
# mfcc18                23075 non-null float64
# mfcc19                23075 non-null float64
# mfcc20                23075 non-null float64
# label                 0 non-null float64
# dtypes: float64(27), object(1)
# memory usage: 4.9+ MB

# %% [markdown]
# # Adding 56 Speaker Noisy Data

# %%
"""

Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

0 - 5,000

"""

for filename in noisy_filenames[:5000]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
"""

Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

5,000 - 10,000

"""

for filename in noisy_filenames[5000:10000]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
"""

Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

10,000 - 15,000

"""

for filename in noisy_filenames[10000:15000]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
"""

Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

15,000 - 20,000

"""

for filename in noisy_filenames[15000:20000]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
"""

Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

20,000 - 23,075

"""

for filename in noisy_filenames[20000:23075]:
    y, sr = librosa.load(filename, sr=sr)
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
    rmse = librosa.feature.rms(y=y)
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zcr = librosa.feature.zero_crossing_rate(y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr)
    to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
    for e in mfcc:
        to_append += f' {np.mean(e)}'
    file = open('56spk_data.csv', 'a', newline='')
    with file:
        writer = csv.writer(file)
        writer.writerow(to_append.split())

# %%
clean_noisy_files_raw = pd.read_csv('56spk_data.csv')

# %%
clean_noisy_files = clean_noisy_files_raw[:]

# %%
clean_noisy_files.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46150 entries, 0 to 46149
# Data columns (total 28 columns):
# filename              46150 non-null object
# chroma_stft           46150 non-null float64
# rmse                  46150 non-null float64
# spectral_centroid     46150 non-null float64
# spectral_bandwidth    46150 non-null float64
# rolloff               46150 non-null float64
# zero_crossing_rate    46150 non-null float64
# mfcc1                 46150 non-null float64
# mfcc2                 46150 non-null float64
# mfcc3                 46150 non-null float64
# mfcc4                 46150 non-null float64
# mfcc5                 46150 non-null float64
# mfcc6                 46150 non-null float64
# mfcc7                 46150 non-null float64
# mfcc8                 46150 non-null float64
# mfcc9                 46150 non-null float64
# mfcc10                46150 non-null float64
# mfcc11                46150 non-null float64
# mfcc12                46150 non-null float64
# mfcc13                46150 non-null float64
# mfcc14                46150 non-null float64
# mfcc15                46150 non-null float64
# mfcc16                46150 non-null float64
# mfcc17                46150 non-null float64
# mfcc18                46150 non-null float64
# mfcc19                46150 non-null float64
# mfcc20                46150 non-null float64
# label                 0 non-null float64
# dtypes: float64(27), object(1)
# memory usage: 9.9+ MB

# %% [markdown]
# # Cleaning the 56 Speaker Data

# %%
raw = pd.read_csv('56spk_data.csv')

# %%
data = raw[:]

# %%
data.sample(5)
# Out:
#                              filename  chroma_stft      rmse  \
# 932    clean_trainset_56/p284_412.wav     0.706042  0.022525
# 8163   clean_trainset_56/p281_251.wav     0.616139  0.035525
# 30190  noisy_trainset_56/p260_060.wav     0.547418  0.052365
# 39159  noisy_trainset_56/p283_038.wav     0.519330  0.050535
# 6240   clean_trainset_56/p281_290.wav     0.655137  0.037851
#
#        spectral_centroid  spectral_bandwidth       rolloff  \
# 932          4025.795488         5917.725382  11007.751465
# 8163         3002.491204         4770.328960   6577.466114
# 30190        7275.999900         7447.995488  17207.089206
# 39159        3276.867945         4623.797383   6590.165441
# 6240         3227.583498         5181.921185   7901.717692
#
#        zero_crossing_rate       mfcc1       mfcc2      mfcc3  ...    mfcc12  \
# 932              0.019814 -518.940308  102.143326  30.772022  ...  3.213855
# 8163             0.031893 -395.062653  146.029312  15.786738  ...  4.807450
# 30190            0.121953 -227.697937   70.197777  32.587841  ...  0.532672
# 39159            0.044188 -325.090149  126.364471  14.666008  ... -0.540777
# 6240             0.030610 -431.755646  132.959396  26.752766  ...  3.921981
#
#          mfcc13     mfcc14    mfcc15    mfcc16    mfcc17    mfcc18     mfcc19  \
# 932    1.523890   0.592393  7.486799  9.970773  4.169780  6.830481  10.997311
# 8163   3.979466  10.009216  6.212143  4.377409  4.082965  7.780740   4.024414
# 30190  0.320690   0.056217 -2.376712  3.807773  1.745092  3.859175   0.489513
# 39159  2.961339   1.348370  3.119751  4.554276  1.446981  3.491709   0.589859
# 6240   6.827603   6.488452  4.442631  2.897282  6.754910  6.774094   3.763283
#
#          mfcc20  label
# 932    4.707895    NaN
# 8163  -3.482327    NaN
# 30190  0.883172    NaN
# 39159  4.806844    NaN
# 6240   0.619696    NaN
#
# [5 rows x 28 columns]

# %%
data.loc[:23075, 'label'] = 'clean'
data.loc[23075:46150, 'label'] = 'noisy'
data.drop(columns=['filename'], inplace=True)

# %%
data.sample(10)
# Out:
#        chroma_stft      rmse  spectral_centroid  spectral_bandwidth  \
# 20232     0.542325  0.042130        3672.235755         5164.117348
# 8072      0.573389  0.052677        3776.909845         5457.374303
# 40277     0.488446  0.065583        3814.917013         4851.197708
# 4045      0.516700  0.050167        3384.504587         4703.518232
# 9899      0.639202  0.035458        4499.946669         5913.616417
# 16907     0.568862  0.039572        3125.432213         4617.291493
# 30898     0.544155  0.058273        2909.498559         4276.188877
# 15875     0.571597  0.040098        4267.691727         5009.440263
# 41217     0.443589  0.069608        3413.739170         5038.307036
# 16849     0.584697  0.021788        3940.113045         6042.336533
#
#             rolloff  zero_crossing_rate       mfcc1       mfcc2      mfcc3  \
# 20232   8824.174860            0.041489 -406.803131  120.104782   9.950170
# 8072    9887.276786            0.040516 -408.056458  104.150055  11.996463
# 40277   7824.237805            0.070305 -228.032547  119.182678  10.096392
# 4045    7841.446619            0.049892 -369.164001  123.999168   8.309220
# 9899   11528.793668            0.052024 -432.604126   93.617142  18.839315
# 16907   6651.797715            0.043884 -386.144806  132.297150  18.131559
# 30898   5806.995107            0.047422 -256.821625  143.771851  -0.138201
# 15875   9149.919181            0.074818 -362.221558  104.941528   4.865733
# 41217   7725.943688            0.041048 -255.590057  128.363190  22.849445
# 16849   9933.401065            0.028686 -481.333496   87.537483  22.933809
#
#            mfcc4  ...    mfcc12     mfcc13    mfcc14    mfcc15    mfcc16  \
# 20232  11.795589  ...  7.925335   2.122528  0.345460  2.257390  2.768185
# 8072   18.034605  ...  8.454062   4.780378 -3.270248  8.604428  9.395601
# 40277  37.126602  ... -1.421483   0.399316  1.891203 -2.388988  2.365268
# 4045   26.233664  ...  1.107222 -11.634656 -1.392704  7.923732  9.645510
# 9899   27.256821  ...  7.996255   4.265562  4.571117  6.088586  6.375970
# 16907  16.597065  ...  8.466214   5.568958  1.470499  4.326536  5.714639
# 30898  25.113985  ...  2.382689   3.376360  1.060561  2.377603  2.851367
# 15875  26.891096  ...  6.322588   6.308614  5.328129  5.518677  6.990089
# 41217  27.936737  ... -1.583213   2.931405 -0.555268  1.590832  5.267771
# 16849  19.088123  ... -2.626060   1.260120  2.179458  3.730605  7.675636
#
#          mfcc17    mfcc18    mfcc19    mfcc20  label
# 20232  3.059754  0.325635 -0.571524 -2.860300  clean
# 8072   4.024442  6.895445  5.099836  1.223441  clean
# 40277  1.536937  4.389834  3.406673  2.748689  noisy
# 4045  -0.276519  5.672630  6.886919  4.937031  clean
# 9899   3.603000  1.476001  4.686839  2.530262  clean
# 16907  6.142548  3.885145  1.219469 -0.652907  clean
# 30898 -2.778695  1.692895  3.609602  0.033399  noisy
# 15875  2.721604  0.792801  3.044589 -1.104889  clean
# 41217 -2.349782  4.256933  1.858701  2.653087  noisy
# 16849  6.593771  3.378117  2.138854  5.675403  clean
#
# [10 rows x 27 columns]

# %%
data.to_csv('56spk_clean_data.csv')

# %% [markdown]
# # Training the 56 Speaker Model

# %%
type_list = data.iloc[:, -1]
encoder = LabelEncoder()
y = encoder.fit_transform(type_list)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(np.array(data.iloc[:, :-1], dtype = float))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 36920
# 36920

# %%
print(len(X_test))
print(len(y_test))
# Out:
# 9230
# 9230

# %%
model = models.Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))

model.add(layers.Dense(128, activation='relu'))

# model.add(layers.Dense(32, activation='relu'))

# model.add(layers.Dense(16, activation='sigmoid'))

model.add(layers.Dense(2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 256)               6912
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 40,066
# Trainable params: 40,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(X_train,
                    y_train,
                    epochs=20,
                    batch_size=128,
                   )
# Out:
# Epoch 1/20
# 36920/36920 [==============================] - 1s 19us/step - loss: 0.0517 - accuracy: 0.9839
# Epoch 2/20
# 36920/36920 [==============================] - 1s 15us/step - loss: 0.0156 - accuracy: 0.9949
# Epoch 3/20
# 36920/36920 [==============================] - 1s 26us/step - loss: 0.0126 - accuracy: 0.9960
# Epoch 4/20
# 36920/36920 [==============================] - 1s 17us/step - loss: 0.0110 - accuracy: 0.9965
# Epoch 5/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0088 - accuracy: 0.9969
# Epoch 6/20
# 36920/36920 [==============================] - 1s 19us/step - loss: 0.0075 - accuracy: 0.9972
# Epoch 7/20
# 36920/36920 [==============================] - 1s 17us/step - loss: 0.0066 - accuracy: 0.9978
# Epoch 8/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0069 - accuracy: 0.9977
# Epoch 9/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0064 - accuracy: 0.9978
# Epoch 10/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0041 - accuracy: 0.9984
# Epoch 11/20
# 36920/36920 [==============================] - 1s 17us/step - loss: 0.0045 - accuracy: 0.9984
# Epoch 12/20
# 36920/36920 [==============================] - 1s 17us/step - loss: 0.0058 - accuracy: 0.9978
# Epoch 13/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 14/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0037 - accuracy: 0.9986
# Epoch 15/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 16/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0041 - accuracy: 0.9984
# Epoch 17/20
# 36920/36920 [==============================] - 1s 17us/step - loss: 0.0025 - accuracy: 0.9990
# Epoch 18/20
# 36920/36920 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.99 - 1s 18us/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 19/20
# 36920/36920 [==============================] - 1s 22us/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 20/20
# 36920/36920 [==============================] - 1s 16us/step - loss: 0.0025 - accuracy: 0.9991

# %%
plt.figure(figsize=(10,6))
plt.title("Training loss")
plt.plot( history.history["loss"] )
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.figure(figsize=(10,6))
plt.title("Training Accuracy")
plt.plot( history.history['accuracy'] )
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
test_loss, test_acc = model.evaluate(X_test,y_test)
# Out:
# 9230/9230 [==============================] - 0s 28us/step

# %%
print('test_acc: ',test_acc)
print('test_loss: ',test_loss)
# Out:
# test_acc:  0.9960996508598328
# test_loss:  0.022229967286885206

# %% [markdown]
# # Logistic and Random Forest Classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve, f1_score, auc, log_loss

# %%
'''

Fitting Logistic Regression Model

'''

# for i in [0.01, 0.05, 0.25, 0.5, 1]:
lr = LogisticRegression(C=0.1)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)
lr_probs = lr.predict_proba(X_test)

print("Accuracy: ", accuracy_score(y_test, lr_pred))
print("Confusion Matrix: ",(confusion_matrix(y_test, lr_pred)))
print("Report: ",(classification_report(y_test, lr_pred)))
# Out:
# Accuracy:  0.9893824485373781
# Confusion Matrix:  [[4609   29]
#  [  69 4523]]
# Report:                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4638
#            1       0.99      0.98      0.99      4592
#
#     accuracy                           0.99      9230
#    macro avg       0.99      0.99      0.99      9230
# weighted avg       0.99      0.99      0.99      9230

# %%
'''

Calculate Log-Loss

'''

print(log_loss(y_test, lr_probs, normalize=False))
print(log_loss(y_test, lr_probs))
# Out:
# 356.2363046880606
# 0.03859548263142585

# %%
'''

Fitting Random Forest Classifier

'''

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)

print("Accuracy: ", accuracy_score(y_test, rf_pred))
# Out:
# Accuracy:  0.9907908992416035

# %%
'''

Plot ROC curve after fitting a model

'''

# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_test))]

# Predict Probabilities
lr_probs = lr.predict_proba(X_test)
rf_probs = rf.predict_proba(X_test)

# keep probabilities for the positive outcome only
lr_probs = lr_probs[:, 1]
rf_probs = rf_probs[:, 1]

# calculate scores
ns_auc = roc_auc_score(y_test, ns_probs)
lr_auc = roc_auc_score(y_test, lr_probs)
rf_auc = roc_auc_score(y_test, rf_probs)

# summarize scores
print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Logistic: ROC AUC=%.3f' % (lr_auc))
print('Random Forest: ROC AUC=%.3f' % (rf_auc))

# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(y_test, lr_probs)
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_probs)

# plot the roc curve for the model
f1,ax1 = plt.subplots(figsize =(18,10))
ax1.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
ax1.plot(lr_fpr, lr_tpr, label='Logistic')
ax1.plot(rf_fpr, rf_tpr, label='Random Forest')

# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.legend()
plt.title('ROC Curve: Different Classification Models', fontsize=20)
# plt.savefig('ROC_classification_models.png')
plt.show();
# Out:
# No Skill: ROC AUC=0.500
# Logistic: ROC AUC=0.999
# Random Forest: ROC AUC=0.999

# %%
'''

Plot Precision-Recall curve after fitting a model

'''

# predict class values

lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
lr_f1, lr_auc = f1_score(y_test, lr_pred), auc(lr_recall, lr_precision)

rf_precision, rf_recall, _ = precision_recall_curve(y_test, rf_probs)
rf_f1, rf_auc = f1_score(y_test, rf_pred), auc(rf_recall, rf_precision)

# summarize scores
print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))
print('Random Forest: f1=%.3f auc=%.3f' % (rf_f1, rf_auc))

# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)

f2,ax2 = plt.subplots(figsize =(18,10))
ax2.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
ax2.plot(lr_recall, lr_precision, label='Logistic')
ax2.plot(rf_recall, rf_precision, label='Random Forest')


# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')

plt.legend()
plt.title('Precision-Recall Curve: Different Classification Models', fontsize=20)
# plt.savefig('precision_recall_classification_models.png')
plt.show();
# Out:
# Logistic: f1=0.989 auc=0.999
# Random Forest: f1=0.991 auc=0.999

# %%
### THIS FILE ENDS HERE ###

# %% [markdown]
# # Importing Test Data

# %%
"""

creating a list of headings

"""

header_test = 'filename chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
for i in range(1, 21):
    header_test += f' mfcc{i}'
header_test += ' label'
header_test = header_test.split()

# %%
sr = 48000

"""

opening and writing the headings to a csv file

"""

file_test = open('test_data.csv', 'w', newline='')
with file_test:
    writer = csv.writer(file_test)
    writer.writerow(header_test)

"""

selecting the folders   

"""

path_test =['clean_dataset', 'noisy_dataset']


"""

Below code selects every file inside both folders. Extracting features from every wav file
and storing them into a csv file

"""

for g in path_test:
    for filename in glob.glob(os.path.join(g, '*.wav')):
        y, sr = librosa.load(filename, sr=sr)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        rmse = librosa.feature.rms(y=y)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
        for e in mfcc:
            to_append += f' {np.mean(e)}'
        to_append += f' {g}'
        file_test = open('test_data.csv', 'a', newline='')
        with file_test:
            writer_test = csv.writer(file_test)
            writer_test.writerow(to_append.split())

# %% [markdown]
# # Cleaning the Test CSV

# %%
test_raw = pd.read_csv('test_data.csv')

# %%
test = test_raw[:]

# %%
test.sample(10)
# Out:
#                         filename  chroma_stft      rmse  spectral_centroid  \
# 1031  noisy_dataset/p257_029.wav     0.481374  0.039773        3347.886549
# 1101  noisy_dataset/p232_353.wav     0.668832  0.055389        4528.711347
# 935   noisy_dataset/p232_137.wav     0.512461  0.071173        6331.809856
# 1069  noisy_dataset/p232_225.wav     0.535185  0.088502        6945.679519
# 1148  noisy_dataset/p232_236.wav     0.575124  0.064328        1715.432923
# 1250  noisy_dataset/p232_211.wav     0.672391  0.091077        3074.458008
# 500   clean_dataset/p257_092.wav     0.620478  0.037437        3963.690184
# 732   clean_dataset/p257_156.wav     0.507411  0.027892        3863.347819
# 1362  noisy_dataset/p257_120.wav     0.547057  0.060898        3595.709246
# 698   clean_dataset/p232_099.wav     0.535007  0.059726        2894.655773
#
#       spectral_bandwidth       rolloff  zero_crossing_rate       mfcc1  \
# 1031         4851.938398   7667.929688            0.039934 -291.919250
# 1101         6536.231533  11916.678139            0.028744 -322.357300
# 935          7562.604297  15796.720806            0.052927 -271.128967
# 1069         7870.512433  17859.822850            0.075870 -205.469360
# 1148         3789.927268   3175.063776            0.011925 -399.885986
# 1250         5273.680273   7637.606534            0.020071 -251.614166
# 500          5964.205117  10578.332937            0.038272 -444.710785
# 732          5323.060691   8904.099771            0.062404 -423.825989
# 1362         5133.104751   8304.452538            0.046144 -276.196503
# 698          4244.009426   6252.403846            0.042914 -376.084747
#
#            mfcc2      mfcc3  ...    mfcc12    mfcc13    mfcc14    mfcc15  \
# 1031  132.073181   7.227456  ...  1.245007  4.635890  1.799177  1.479332
# 1101   94.429810  33.670731  ...  6.051633  0.995707  7.167144  6.189361
# 935    83.679085  55.777794  ...  4.324506  0.200560  1.743950  2.616437
# 1069   80.362030  56.890476  ...  2.405413  0.578641  5.345542  6.194053
# 1148  152.689407  34.666233  ...  9.067727  1.592633  3.148249  3.870684
# 1250  122.096573  19.954430  ...  1.127777  4.738394  7.003510  1.118422
# 500    90.700317  20.600494  ...  3.051041  8.847534  5.537223  1.486503
# 732    91.430954  17.335115  ...  6.680706  6.472764  2.780392 -1.694457
# 1362  125.021790  11.689628  ... -3.248497  4.363384  5.342090 -3.579113
# 698   129.131607   5.430285  ...  3.532119 -1.505414  6.046439  6.645525
#
#         mfcc16    mfcc17    mfcc18    mfcc19    mfcc20          label
# 1031  3.449327  5.728377  4.490350 -1.295645 -1.738474  noisy_dataset
# 1101  8.043468  1.247142  6.607071  4.210517  2.192719  noisy_dataset
# 935   7.273001  6.291157  7.147392  0.790219  1.496347  noisy_dataset
# 1069  5.452226  2.496304  5.719025 -1.484793  0.923947  noisy_dataset
# 1148  6.865670  3.511643  4.463363  4.065269  0.145402  noisy_dataset
# 1250  8.354822  1.910356  5.182644  3.828643  6.724372  noisy_dataset
# 500   2.494074  8.210882  3.243595 -3.106668  1.513851  clean_dataset
# 732   9.464657  9.659921  0.327342 -5.445522  0.877129  clean_dataset
# 1362  4.481107  2.731123  5.575750 -2.273480  4.158601  noisy_dataset
# 698   4.260402  6.309883  4.722117  1.704522 -0.939558  clean_dataset
#
# [10 rows x 28 columns]

# %%
test['label'].replace(to_replace='clean_dataset',value='clean',inplace=True)
test['label'].replace(to_replace='noisy_dataset',value='noisy',inplace=True)
test.drop(columns=['filename'], inplace=True)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py:6786: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
test.sample(10)
# Out:
#       chroma_stft      rmse  spectral_centroid  spectral_bandwidth  \
# 20       0.570576  0.055748        3198.722626         4814.608256
# 526      0.561438  0.037354        3353.910582         5387.295682
# 1091     0.513624  0.077613        2518.350063         4518.884446
# 913      0.591533  0.095246        3186.519119         5243.360005
# 749      0.643188  0.040526        3701.118904         5567.161585
# 400      0.568766  0.035304        3875.533910         5463.699168
# 1348     0.456919  0.052255        2839.628407         4267.874993
# 1539     0.426805  0.041766        3656.812393         4938.691036
# 488      0.617617  0.043021        4074.806368         5672.805208
# 434      0.524282  0.049197        2946.136980         4244.537377
#
#            rolloff  zero_crossing_rate       mfcc1       mfcc2      mfcc3  \
# 20     7258.125000            0.024644 -390.592285  114.726715  17.732119
# 526    8434.320038            0.030519 -412.687958  121.909241  19.485415
# 1091   5664.062500            0.014927 -294.798492  129.643921  12.137397
# 913    7438.990935            0.027310 -231.472977  125.271767  19.283558
# 749    8889.100610            0.031479 -441.892059   92.267387  14.563829
# 400    9653.676471            0.045851 -434.689636   97.250313  14.015547
# 1348   6144.181034            0.037625 -338.413483  144.591705   6.363937
# 1539   8298.100490            0.057328 -275.573883  125.922409   9.351147
# 488   10325.532511            0.042616 -436.634735   77.442543  11.143861
# 434    6138.569937            0.040949 -388.223083  136.092178   7.433791
#
#           mfcc4  ...    mfcc12    mfcc13    mfcc14    mfcc15    mfcc16  \
# 20    24.156233  ...  3.298252 -0.078050  4.595935  0.308052  2.375388
# 526    7.442644  ...  3.945361  9.385000  4.260778  0.088026  2.912663
# 1091  24.965145  ...  4.470892  4.692489  5.312146  4.643301  5.375102
# 913   20.814613  ...  3.458925  5.583310  7.451666  1.589216  8.371895
# 749   22.172731  ...  4.287526 -0.048259  5.233430  7.886896  8.368106
# 400   18.886780  ...  6.032449  8.150064  2.488801  2.985852  7.073934
# 1348  24.042345  ...  2.056384  1.187758  4.450588  2.629140  5.120103
# 1539  22.614813  ... -1.094461  4.507504  0.744015 -2.545901  3.789707
# 488   28.069582  ...  5.749087 -0.617095  5.499233  3.291248  4.808319
# 434   16.516567  ...  3.794336 -5.397676  5.434323  3.816814  0.314468
#
#         mfcc17     mfcc18    mfcc19    mfcc20  label
# 20    6.272243   6.562377  4.215570 -0.202781  clean
# 526   6.356308   3.774719 -3.329163 -0.290654  clean
# 1091  1.754897  10.029657  0.758825  4.777404  noisy
# 913   4.940680   5.797746  0.524805  1.561113  noisy
# 749   4.675375   4.201132  6.551585  3.609758  clean
# 400   7.340174   4.630106 -0.865986  1.613326  clean
# 1348  1.769152   5.439353  2.899412 -3.059319  noisy
# 1539  3.372223   1.984139 -1.928500 -0.895816  noisy
# 488   8.023574   4.692338  3.386367  2.413785  clean
# 434   4.909488   5.480031  3.818551  0.238676  clean
#
# [10 rows x 27 columns]

# %%
# data.to_csv('clean_test_data.csv')

# %% [markdown]
# # Testing the Model

# %%
test_list = test.iloc[:, -1]
test_encoder = LabelEncoder()
y_test = test_encoder.fit_transform(test_list)

# %%
train_scaler = StandardScaler()
X_test = train_scaler.fit_transform(np.array(test.iloc[:, :-1], dtype = float))

# %%
test_loss, test_acc = model.evaluate(X_test,y_test)
# Out:
# 1648/1648 [==============================] - 0s 26us/step

# %%
print('test_acc: ',test_acc)
print('test_loss: ',test_loss)
# Out:
# test_acc:  0.919296145439148
# test_loss:  0.4936474578893626
